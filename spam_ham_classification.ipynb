# %% [markdown]
# # process
# - Text analysis  50%
# - Text Transformation 40%
# - Model development 5%
# - ui application 5%

# %% [markdown]
# # text analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# plt.style.available    --- use to see available themes
plt.style.use('ggplot')

# %%
sns.set_style('whitegrid')

# %%
import nltk

# %%
nltk.download('word_tokenize')
# Out:
# [nltk_data] Error loading word_tokenize: Package 'word_tokenize' not
# [nltk_data]     found in index
# False

# %%
from nltk.corpus import stopwords
import string
from nltk.tokenize import word_tokenize
import spacy

# %%
spacy.load('en_core_web_sm')

# %%
messages = pd.read_csv('dataset/spam.csv', encoding='latin1')

# %%
messages.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
messages.drop(labels= ['Unnamed: 2','Unnamed: 3','Unnamed: 4'],axis=1,inplace=True)

# %%
messages.columns=['category','text']
messages.head()
# Out:
#   category                                               text
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
# category    5572 non-null object
# text        5572 non-null object
# dtypes: object(2)
# memory usage: 87.1+ KB

# %%
messages.category.value_counts()
# Out:
# ham     4825
# spam     747
# Name: category, dtype: int64

# %%
messages.category.value_counts().plot(kind='pie',explode=[0,.1],figsize=(6,6),autopct='%.2f%%')
plt.title("ham vs spam")
plt.legend(['Normal',"spam"])
plt.show()

# %%
messages.groupby('text')['category'].agg([len,np.max]).sort_values(by='len',ascending=False).head(10)
# Out:
#                                                     len  amax
# text
# Sorry, I'll call later                               30   ham
# I cant pick the phone right now. Pls send a mes...   12   ham
# Ok...                                                10   ham
# Your opinion about me? 1. Over 2. Jada 3. Kusru...    4   ham
# Wen ur lovable bcums angry wid u, dnt take it s...    4   ham
# Please call our customer service representative...    4  spam
# Okie                                                  4   ham
# Say this slowly.? GOD,I LOVE YOU &amp; I NEED Y...    4   ham
# 7 wonders in My WORLD 7th You 6th Ur style 5th ...    4   ham
# Ok.                                                   4   ham

# %% [markdown]
# individual spam/ham words

# %%
spam_messages = messages[messages['category']=='spam']['text']
ham_messages = messages[messages['category']=='ham']['text']

# %%
spam_words= []
ham_words= []

# %%
def extract_spam_words(text):
    global spam_words
    words = [word.lower() for word in word_tokenize(text) if word.lower() not in stopwords.words('english') and word.lower().isalpha()]
    spam_words.extend(words)

def extract_ham_words(text):
    global ham_words
    words = [word.lower() for word in word_tokenize(text) if word.lower() not in stopwords.words('english') and word.lower().isalpha()]
    ham_words.extend(words)

# %%
  for word in word_tokenize("i just keep yapping, while my students sleep"):
      if word.lower() not in stopwords.words('english'):
          print(word)
# Out:
# keep
# yapping
# ,
# students
# sleep

# %%
spam_messages.apply(extract_spam_words)
# Out:
# 2       None
# 5       None
# 8       None
# 9       None
# 11      None
# 12      None
# 15      None
# 19      None
# 34      None
# 42      None
# 54      None
# 56      None
# 65      None
# 67      None
# 68      None
# 93      None
# 95      None
# 113     None
# 116     None
# 119     None
# 120     None
# 122     None
# 133     None
# 134     None
# 138     None
# 146     None
# 158     None
# 159     None
# 163     None
# 164     None
#         ...
# 5342    None
# 5364    None
# 5365    None
# 5366    None
# 5368    None
# 5370    None
# 5377    None
# 5378    None
# 5381    None
# 5427    None
# 5443    None
# 5449    None
# 5456    None
# 5460    None
# 5462    None
# 5466    None
# 5467    None
# 5468    None
# 5482    None
# 5487    None
# 5492    None
# 5497    None
# 5501    None
# 5524    None
# 5526    None
# 5537    None
# 5540    None
# 5547    None
# 5566    None
# 5567    None
# Name: text, Length: 747, dtype: object

# %%
ham_messages.apply(extract_ham_words)
print(ham_words)
# Out:
# ne', 'come', 'get', 'b', 'quite', 'diff', 'guess', 'rite', 'reach', 'ur', 'home', 'lt', 'gt', 'minutes', 'babe', 'answering', 'ca', 'see', 'maybe', 'better', 'reboot', 'ym', 'got', 'photo', 'great', 'think', 'match', 'know', 'thinkin', 'malaria', 'relax', 'children', 'cant', 'handle', 'malaria', 'would', 'worse', 'gastroenteritis', 'takes', 'enough', 'replace', 'loss', 'temp', 'reduce', 'give', 'malaria', 'meds', 'vomit', 'self', 'limiting', 'illness', 'means', 'days', 'completely', 'stop', 'dai', 'downloaded', 'exe', 'file', 'run', 'exe', 'installing', 'yesterday', 'true', 'true', 'business', 'pa', 'selected', 'keep', 'ten', 'rs', 'shelf', 'buy', 'two', 'egg', 'late', 'well', 'thats', 'nice', 'bad', 'cant', 'eat', 'accidentally', 'brought', 'em', 'home', 'box', 'pls', 'needs', 'dat', 'slowly', 'vomit', 'take', 'exam', 'march', 'jane', 'babes', 'goin', 'wrk', 'feel', 'ill', 'lst', 'nite', 'foned', 'already', 'cover', 'chuck', 'nights', 'nt', 'staying', 'port', 'step', 'liao', 'ex', 'die', 'want', 'u', 'stuffs', 'fuck', 'juswoke', 'bed', 'boatin', 'docks', 'slept', 'wid', 'year', 'old', 'spinout', 'giv', 'u', 'da', 'gossip', 'smile', 'pleasure', 'smile', 'pain', 'smile', 'trouble', 'pours', 'like', 'rain', 'smile', 'hurts', 'u', 'smile', 'becoz', 'someone', 'still', 'loves', 'see', 'u', 'smiling', 'heart', 'sory', 'alex', 'nichols', 'middle', 'school', 'turns', 'dealing', 'means', 'u', 'could', 'keep', 'ur', 'words', 'nope', 'still', 'market', 'realise', 'busy', 'guy', 'trying', 'bother', 'get', 'exams', 'outta', 'way', 'try', 'cars', 'day', 'hey', 'project', 'started', 'aha', 'da', 'ok', 'cool', 'see', 'ya', 'uworld', 'site', 'buying', 'qbank', 'buying', 'self', 'assessment', 'also', 'opinion', 'jada', 'kusruthi', 'lovable', 'silent', 'spl', 'character', 'matured', 'stylish', 'simple', 'pls', 'yeah', 'still', 'give', 'ride', 'jay', 'wants', 'work', 'first', 'sound', 'gud', 'chikku', 'tke', 'sleep', 'well', 'gud', 'nyt', 'part', 'checking', 'iq', 'hmm', 'thinking', 'lor', 'course', 'tease', 'know', 'simply', 'must', 'see', 'keep', 'posted', 'prey', 'thanks', 'temales', 'wonderful', 'thank', 'great', 'week', 'thank', 'princess', 'want', 'see', 'nice', 'juicy', 'booty', 'eaten', 'day', 'sitting', 'staring', 'juicy', 'pizza', 'ca', 'eat', 'meds', 'ruining', 'life', 'gud', 'u', 'come', 'n', 'search', 'tat', 'k', 'leaving', 'soon', 'little', 'yeah', 'work', 'fine', 'started', 'last', 'week', 'stuff', 'dull', 'easy', 'guys', 'fun', 'studies', 'alone', 'without', 'anyones', 'help', 'cant', 'need', 'study', 'please', 'tell', 'car', 'keys', 'purse', 'didnt', 'get', 'anything', 'da', 'ok', 'sweet', 'dreams', 'well', 'big', 'surprise', 'fine', 'happy', 'amp', 'cbe', 'chennai', 'help', 'u', 'swoop', 'picking', 'u', 'wherever', 'ur', 'birds', 'r', 'meeting', 'u', 'want', 'anyone', 'calls', 'treadmill', 'say', 'buy', 'make', 'sure', 'working', 'found', 'ad', 'craigslist', 'selling', 'lt', 'gt', 'absolutely', 'love', 'south', 'park', 'recently', 'started', 'watching', 'office', 'see', 'film', 'pls', 'speak', 'wont', 'ask', 'anything', 'friendship', 'storming', 'msg', 'wen', 'u', 'lift', 'phne', 'u', 'say', 'u', 'knw', 'wt', 'real', 'meaning', 'hello', 'name', 'u', 'knw', 'dat', 'girl', 'margaret', 'girlfrnd', 'f', 'grahmbell', 'invnted', 'telphone', 'moral', 'one', 'name', 'person', 'gud', 'care', 'hi', 'darlin', 'kate', 'u', 'doin', 'somethin', 'tonight', 'im', 'going', 'pub', 'called', 'swan', 'something', 'parents', 'one', 'drink', 'phone', 'u', 'anything', 'lar', 'going', 'home', 'dinner', 'u', 'fix', 'teeth', 'take', 'care', 'u', 'wan', 'come', 'dinner', 'tonight', 'u', 'u', 'u', 'b', 'moving', 'flat', 'cos', 'need', 'arrange', 'pick', 'lamp', 'etc', 'take', 'care', 'hello', 'caroline', 'late', 'hi', 'hope', 'ur', 'day', 'good', 'back', 'walk', 'table', 'booked', 'half', 'eight', 'let', 'know', 'ur', 'coming', 'oh', 'yeah', 'clearly', 'fault', 'dunno', 'leh', 'cant', 'remember', 'mayb', 'lor', 'wat', 'time', 'r', 'meeting', 'tmr', 'best' ...

# %%
from wordcloud import WordCloud

# %%
spam_wordcloud = WordCloud(width=600,height=480).generate(" ".join(spam_words))
plt.figure(figsize=(10,8))
plt.imshow(spam_wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
ham_wordcloud = WordCloud(width=800,height=400).generate(" ".join(ham_words))
plt.figure(figsize=(10,8))
plt.imshow(ham_wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
spam_words = np.array(spam_words)
pd.Series(spam_words).value_counts().head(10)
# Out:
# call      346
# free      217
# txt       156
# ur        144
# u         144
# mobile    123
# text      121
# stop      114
# claim     113
# reply     104
# dtype: int64

# %%
ham_words = np.array(ham_words)
pd.Series(ham_words).value_counts().head(10)
# Out:
# u       974
# gt      318
# lt      316
# get     301
# ok      246
# go      246
# got     242
# ur      237
# know    234
# like    231
# dtype: int64

# %%
messages['messageLength'] = messages['text'].apply(len)
messages.head()
# Out:
#   category                                               text  messageLength
# 0      ham  Go until jurong point, crazy.. Available only ...            111
# 1      ham                      Ok lar... Joking wif u oni...             29
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...            155
# 3      ham  U dun say so early hor... U c already then say...             49
# 4      ham  Nah I don't think he goes to usf, he lives aro...             61

# %%
f, ax = plt.subplots(1,2,figsize=(20,6))
sns.distplot(messages[messages['category']=='spam']['messageLength'], bins = 20, ax= ax[0])
ax[0].set_xlabel('Spam message word length')
sns.distplot(messages[messages['category']=='ham']['messageLength'], bins = 20, ax= ax[1])
ax[1].set_xlabel('Normal message word length')
plt.show()

# %% [markdown]
# # Text Transformation

# %% [markdown]
# clean punctuations & stopwords & stemming
# - stemming example
#     - playing
#     - plays
#     - *play* - this will be called a stem word also called 'lemma'
#     - playable
#     - playthrough

# %%
from nltk.stem import SnowballStemmer

# %%
stemmer = SnowballStemmer('english')

# %%
def cleanupText(message):
    message =  message.translate(str.maketrans('','',string.punctuation)) # remove basic puncutation
    words = [stemmer.stem(word) for word in message.split() if word.lower() not in stopwords.words('english')]
    return " ".join(words)

# %%
messages.text = messages.text.apply(cleanupText)

# %%
messages.head()
# Out:
#   category                                               text  messageLength
# 0      ham  go jurong point crazi avail bugi n great world...            111
# 1      ham                              ok lar joke wif u oni             29
# 2     spam  free entri 2 wkli comp win fa cup final tkts 2...            155
# 3      ham                u dun say earli hor u c alreadi say             49
# 4      ham          nah dont think goe usf live around though             61

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vec = TfidfVectorizer(encoding='latin1',strip_accents='unicode',stop_words="english")
features = vec.fit_transform(messages.text)
features=features.toarray()

# %% [markdown]
# # model application

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
category_enc = LabelEncoder()
messages.category = category_enc.fit_transform(messages.category)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(features, messages.category, test_size=.2)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import fbeta_score

# %%
from sklearn.naive_bayes import GaussianNB

# %%
clf = GaussianNB()
clf.fit(xtrain,ytrain)
ypred =  clf.predict(xtest)

# %%
fbeta_score(ytest,ypred,beta=.5)
# Out:
# 0.6290849673202614

# %%
import pickle

# %%
def save_model(model, path="models/clf.pk"):
    with open(path,'wb') as file:
        pickle.dump(model, file)
    print("success")

# %%
def save_model(model, path="models/TfidVectorizer.pk"):
    with open(path,'wb') as file:
        pickle.dump(model, file)
    print("success")

# %%
save_model(clf)
# Out:
# success

# %%
save_model(TfidfVectorizer)
# Out:
# success
